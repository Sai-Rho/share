# %% [markdown]
# # Wine dataset

# %% [markdown]
# Installing mysql-connector-python

# %% [markdown]
# Data preprocessing

# %% [markdown]
# Data visualization

# %% [markdown]
# EDA process

# %%
# !pip install mysql-connector-python

# %%
#importing mysql.connector lib

import mysql.connector
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %% [markdown]
# Here below we are connecting the mysql with lost host by provinding host,port,user,password and database to extract data the details are as shown below

# %%
import pandas as pd
con=mysql.connector.connect(
    host="localhost",
    port=3306,
    user="root",
    password='root',
    database='project')

data=pd.read_sql_query('select * from winedata',con)
data
data.head(15)
# Out:
#    Class Alcohol Malic_acid   Ash Alcalinity_of_ash Magnesium Total_phenols  \
# 0      1   14.23       1.71  2.43              15.6       127           2.8
# 1      1    13.2       1.78  2.14              11.2       100          2.65
# 2      1   13.16       2.36  2.67              18.6       101           2.8
# 3      1   14.37       1.95   2.5              16.8       113          3.85
# 4      1   13.24       2.59  2.87                21       118           2.8
# 5      1    14.2       1.76  2.45              15.2       112          3.27
# 6      1   14.39       1.87  2.45              14.6        96           2.5
# 7      1   14.06       2.15  2.61              17.6       121           2.6
# 8      1   14.83       1.64  2.17                14        97           2.8
# 9      1   13.86       1.35  2.27                16        98          2.98
# 10     1    14.1       2.16   2.3                18       105          2.95
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Class                 178 non-null    object
#  1   Alcohol               178 non-null    object
#  2   Malic_acid            178 non-null    object
#  3   Ash                   178 non-null    object
#  4   Alcalinity_of_ash     178 non-null    object
#  5   Magnesium             178 non-null    object
#  6   Total_phenols         178 non-null    object
#  7   Flavanoids            178 non-null    object
#  8   Nonflavanoid_phenols  178 non-null    object
#  9   Proanthocyanins       178 non-null    object
#  10  Color_intensity       178 non-null    object
#  11  Hue                   178 non-null    object
#  12  diluted_wines         178 non-null    object
#  13  Proline               178 non-null    object
# dtypes: object(14)
# memory usage: 19.6+ KB

# %%
data=data.astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Class                 178 non-null    float64
#  1   Alcohol               178 non-null    float64
#  2   Malic_acid            178 non-null    float64
#  3   Ash                   178 non-null    float64
#  4   Alcalinity_of_ash     178 non-null    float64
#  5   Magnesium             178 non-null    float64
#  6   Total_phenols         178 non-null    float64
#  7   Flavanoids            178 non-null    float64
#  8   Nonflavanoid_phenols  178 non-null    float64
#  9   Proanthocyanins       178 non-null    float64
#  10  Color_intensity       178 non-null    float64
#  11  Hue                   178 non-null    float64
#  12  diluted_wines         178 non-null    float64
#  13  Proline               178 non-null    float64
# dtypes: float64(14)
# ...

# %% [markdown]
# # Data Visualization and EDA

# %%
print(data['Class'].value_counts())
data['Class'].value_counts().plot.bar()
# Out:
# 2.0    71
# 1.0    59
# 3.0    48
# Name: Class, dtype: int64

# %%
data.describe()
# Out:
#             Class     Alcohol  Malic_acid         Ash  Alcalinity_of_ash  \
# count  178.000000  178.000000  178.000000  178.000000         178.000000
# mean     1.938202   13.000618    2.336348    2.366517          19.494944
# std      0.775035    0.811827    1.117146    0.274344           3.339564
# min      1.000000   11.030000    0.740000    1.360000          10.600000
# 25%      1.000000   12.362500    1.602500    2.210000          17.200000
# 50%      2.000000   13.050000    1.865000    2.360000          19.500000
# 75%      3.000000   13.677500    3.082500    2.557500          21.500000
# max      3.000000   14.830000    5.800000    3.230000          30.000000
#
#         Magnesium  Total_phenols  Flavanoids  Nonflavanoid_phenols  \
# count  178.000000     178.000000  178.000000            178.000000
# mean    99.741573       2.295112    2.029270              0.361854
# std     14.282484       0.625851    0.998859              0.124453
# ...

# %%
sb.boxplot(data=data)

# %%
sb.barplot(x='Alcohol', y='Proline',data=data)

# %%
sb.lmplot(x='Proline', y='Flavanoids', hue='Class', data=data)

# %%
sb.lmplot(x='Hue', y='Flavanoids', hue='Class', data=data)

# %%
sb.lmplot(x='Color_intensity', y='Flavanoids', hue='Class', data=data)

# %%
sb.boxplot(x='Class', y='diluted_wines',data=data)

# %%
data.corr()
# Out:
#                          Class   Alcohol  Malic_acid       Ash  \
# Class                 1.000000 -0.328222    0.437776 -0.049643
# Alcohol              -0.328222  1.000000    0.094397  0.211545
# Malic_acid            0.437776  0.094397    1.000000  0.164045
# Ash                  -0.049643  0.211545    0.164045  1.000000
# Alcalinity_of_ash     0.517859 -0.310235    0.288500  0.443367
# Magnesium            -0.209179  0.270798   -0.054575  0.286587
# Total_phenols        -0.719163  0.289101   -0.335167  0.128980
# Flavanoids           -0.847498  0.236815   -0.411007  0.115077
# Nonflavanoid_phenols  0.489109 -0.155929    0.292977  0.186230
# Proanthocyanins      -0.499130  0.136698   -0.220746  0.009652
# Color_intensity       0.265668  0.546364    0.248985  0.258887
# Hue                  -0.617369 -0.071747   -0.561296 -0.074667
# diluted_wines        -0.788230  0.072343   -0.368710  0.003911
# Proline              -0.633717  0.643720   -0.192011  0.223626
#
# ...

# %%
sb.lmplot(x='Total_phenols', y ='Flavanoids', data=data)

# %%
plt.figure(figsize=(18,15))
sb.heatmap(data.corr(),annot=True)

# %%
sb.pairplot(data)

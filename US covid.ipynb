# %% [markdown]
# # UnitedStates_COVID_19

# %% [markdown]
# Analysing the USCovid_19 Dataset
#
# Considering a perticular date's data

# %% [markdown]
# Data Analysing
#
# Data Visualization
#
# Exploratory data analysis (EDA)
#
# Conclusion

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
da=pd.read_csv('uscovid.csv')

# %%
da
# Out:
#               Province_State Country_Region          Last_Update      Lat  \
# 0                    Alabama             US  2020-05-21 02:32:54  32.3182
# 1                     Alaska             US  2020-05-21 02:32:54  61.3707
# 2             American Samoa             US  2020-05-21 02:32:54 -14.2710
# 3                    Arizona             US  2020-05-21 02:32:54  33.7298
# 4                   Arkansas             US  2020-05-21 02:32:54  34.9697
# 5                 California             US  2020-05-21 02:32:54  36.1162
# 6                   Colorado             US  2020-05-21 02:32:54  39.0598
# 7                Connecticut             US  2020-05-21 02:32:54  41.5978
# 8                   Delaware             US  2020-05-21 02:32:54  39.3185
# 9           Diamond Princess             US  2020-05-21 02:32:54      NaN
# 10      District of Columbia             US  2020-05-21 02:32:54  38.8974
# 11                   Florida             US  2020-05-21 02:32:54  27.7663
# ...

# %% [markdown]
# Dataset description
#
# Province_State - The name of the State within the USA.
#
# Country_Region - The name of the Country (US).
#
# Last_Update - The most recent date the file was pushed.
#
# Lat - Latitude.
#
# Long_ - Longitude.
#
# Confirmed - Aggregated confirmed case count for the state.
#
# Deaths - Aggregated Death case count for the state.
#
# Recovered - Aggregated Recovered case count for the state.
#
# Active - Aggregated confirmed cases that have not been resolved (Active = Confirmed - Recovered - Deaths).
#
# FIPS - Federal Information Processing Standards code that uniquely identifies counties within the USA.
#
# Incident_Rate - confirmed cases per 100,000 persons.
#
# People_Tested - Total number of people who have been tested.
#
# People_Hospitalized - Total number of people hospitalized.
#
# Mortality_Rate - Number recorded deaths * 100/ Number confirmed cases.
#
# UID - Unique Identifier for each row entry.
#
# ISO3 - Officialy assigned country code identifiers.
#
# Testing_Rate - Total number of people tested per 100,000 persons.
#
# Hospitalization_Rate - Total number of people hospitalized * 100/ Number of confirmed cases.

# %%
#these are the dataset columns

da.columns
# Out:
# Index(['Province_State', 'Country_Region', 'Last_Update', 'Lat', 'Long_',
#        'Confirmed', 'Deaths', 'Recovered', 'Active', 'FIPS', 'Incident_Rate',
#        'People_Tested', 'People_Hospitalized', 'Mortality_Rate', 'UID', 'ISO3',
#        'Testing_Rate', 'Hospitalization_Rate'],
#       dtype='object')

# %%
#Data types of coluns
da.dtypes
# Out:
# Province_State           object
# Country_Region           object
# Last_Update              object
# Lat                     float64
# Long_                   float64
# Confirmed                 int64
# Deaths                    int64
# Recovered               float64
# Active                  float64
# FIPS                      int64
# Incident_Rate           float64
# People_Tested           float64
# People_Hospitalized     float64
# Mortality_Rate          float64
# UID                       int64
# ISO3                     object
# Testing_Rate            float64
# Hospitalization_Rate    float64
# dtype: object

# %%
#Finding the null values and data types of the datset

da.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Province_State        58 non-null     object
#  1   Country_Region        58 non-null     object
#  2   Last_Update           58 non-null     object
#  3   Lat                   56 non-null     float64
#  4   Long_                 56 non-null     float64
#  5   Confirmed             58 non-null     int64
#  6   Deaths                58 non-null     int64
#  7   Recovered             42 non-null     float64
#  8   Active                58 non-null     float64
#  9   FIPS                  58 non-null     int64
#  10  Incident_Rate         56 non-null     float64
#  11  People_Tested         56 non-null     float64
#  12  People_Hospitalized   33 non-null     float64
#  13  Mortality_Rate        57 non-null     float64
#  14  UID                   58 non-null     int64
# ...

# %%
# Finding the un-unique values in each and every column

da.nunique()
# Out:
# Province_State          58
# Country_Region           1
# Last_Update              1
# Lat                     56
# Long_                   56
# Confirmed               58
# Deaths                  56
# Recovered               42
# Active                  58
# FIPS                    58
# Incident_Rate           56
# People_Tested           56
# People_Hospitalized     33
# Mortality_Rate          57
# UID                     58
# ISO3                     6
# Testing_Rate            56
# Hospitalization_Rate    33
# dtype: int64

# %% [markdown]
# # Elploratory Data Analysis (EDA)

# %% [markdown]
# Univariate plot

# %%
plt.figure(figsize=(20,6))
sb.set_style('dark')
sb.distplot(da['Confirmed'])

# %%
plt.figure(figsize=(20,6))
sb.set_style('dark')
sb.distplot(da['Deaths'])

# %%
plt.figure(figsize=(20,6))
sb.set_style('dark')
sb.distplot(da['Recovered'])

# %% [markdown]
# Bivariate plot

# %%
plt.figure(figsize=(20,6))
plt.xticks(rotation=90)
sb.barplot(x='Province_State',y='Confirmed',data=da)

# %%
plt.figure(figsize=(20,6))
plt.xticks(rotation=90)
sb.barplot(x='Province_State',y='Deaths',data=da)

# %%
plt.figure(figsize=(20,6))
plt.xticks(rotation=90)
sb.barplot(x='Province_State',y='Recovered',data=da)

# %%
plt.figure(figsize=(20,6))
plt.xticks(rotation=90)
sb.barplot(x='Province_State',y='Active',data=da)

# %%
plt.figure(figsize=(20,6))
plt.xticks(rotation=90)
sb.barplot(x='Province_State',y='People_Tested',data=da)

# %%
plt.figure(figsize=(20,6))
plt.xticks(rotation=90)
sb.barplot(x='Province_State',y='People_Hospitalized',data=da)

# %%
plt.figure(figsize=(20,6))
plt.xticks(rotation=90)
sb.barplot(x='Province_State',y='Mortality_Rate',data=da)

# %%
plt.figure(figsize=(20,6))
plt.xticks(rotation=90)
sb.lineplot(x='Active',y='Deaths',data=da)

# %%
plt.figure(figsize=(20,6))
plt.xticks(rotation=90)
sb.lineplot(x='Recovered',y='Deaths',data=da)

# %% [markdown]
# # Data Preprocessing

# %%
data=da.drop(['Province_State',"Country_Region","Last_Update","Lat","Long_","UID","ISO3","FIPS"],axis=1)

# %%
data
# Out:
#     Confirmed  Deaths  Recovered    Active  Incident_Rate  People_Tested  \
# 0       13052     522        NaN   12530.0     266.194321       164450.0
# 1         401      10      352.0      39.0      54.815493        37045.0
# 2           0       0        NaN       0.0       0.000000          124.0
# 3       14906     747     3773.0   10386.0     204.788838       165435.0
# 4        5003     107     3852.0    1044.0     165.782801        96258.0
# 5       85997    3497        NaN   82500.0     217.646575      1380120.0
# 6       22797    1299     3478.0   18020.0     395.868121       131837.0
# 7       39017    3529     6264.0   29224.0    1094.357902       190718.0
# 8        8194     310     3965.0    3919.0     841.476990        45412.0
# 9          49       0        NaN      49.0            NaN            NaN
# 10       7551     407     1059.0    6085.0    1069.927127        40419.0
# 11      47471    2096        NaN   45375.0     221.024217       771348.0
# ...

# %% [markdown]
# Filling the missing values with mean() as shown below

# %%
data['Recovered']=data['Recovered'].fillna(value=data["Recovered"].mean())
data['Incident_Rate']=data['Incident_Rate'].fillna(value=data["Incident_Rate"].mean())
data['People_Tested']=data['People_Tested'].fillna(value=data["People_Tested"].mean())
data['People_Hospitalized']=data['People_Hospitalized'].fillna(value=data["People_Hospitalized"].mean())
data['Mortality_Rate']=data['Mortality_Rate'].fillna(value=data["Mortality_Rate"].mean())
data['Testing_Rate']=data['Testing_Rate'].fillna(value=data["Testing_Rate"].mean())
data['Hospitalization_Rate']=data['Hospitalization_Rate'].fillna(value=data["Hospitalization_Rate"].mean())

# %%
data
# Out:
#     Confirmed  Deaths     Recovered    Active  Incident_Rate  People_Tested  \
# 0       13052     522   7007.428571   12530.0     266.194321   1.644500e+05
# 1         401      10    352.000000      39.0      54.815493   3.704500e+04
# 2           0       0   7007.428571       0.0       0.000000   1.240000e+02
# 3       14906     747   3773.000000   10386.0     204.788838   1.654350e+05
# 4        5003     107   3852.000000    1044.0     165.782801   9.625800e+04
# 5       85997    3497   7007.428571   82500.0     217.646575   1.380120e+06
# 6       22797    1299   3478.000000   18020.0     395.868121   1.318370e+05
# 7       39017    3529   6264.000000   29224.0    1094.357902   1.907180e+05
# 8        8194     310   3965.000000    3919.0     841.476990   4.541200e+04
# 9          49       0   7007.428571      49.0     396.230806   2.258534e+05
# 10       7551     407   1059.000000    6085.0    1069.927127   4.041900e+04
# ...

# %%
# the Correlation between the different variables

data.corr()
# Out:
#                       Confirmed    Deaths  Recovered    Active  Incident_Rate  \
# Confirmed              1.000000  0.982191   0.822547  0.985218       0.708436
# Deaths                 0.982191  1.000000   0.830223  0.954378       0.710105
# Recovered              0.822547  0.830223   1.000000  0.725085       0.542795
# Active                 0.985218  0.954378   0.725085  1.000000       0.700926
# Incident_Rate          0.708436  0.710105   0.542795  0.700926       1.000000
# People_Tested          0.824136  0.739634   0.711255  0.826144       0.441669
# People_Hospitalized    0.869267  0.908279   0.761829  0.835938       0.551076
# Mortality_Rate         0.382537  0.427127   0.322160  0.367626       0.353882
# Testing_Rate           0.332464  0.344465   0.220597  0.321395       0.620621
# Hospitalization_Rate   0.287471  0.298225   0.231692  0.284564       0.196029
#
#                       People_Tested  People_Hospitalized  Mortality_Rate  \
# ...

# %%
# This heatmap shows the Correlation between the different variables

plt.figure(figsize=(12,8))
sb.heatmap(da.corr(),annot=True)

# %%
# This clustermap shows the Correlation between the different variables

plt.figure(figsize=(12,8))
sb.clustermap(da.corr(),annot=True)

# %% [markdown]
# pairwise plot of relationship with the dataset
#
# Multivariate plotting of dataset

# %%
sb.pairplot(data)

# %% [markdown]
# # Conclusion

# %% [markdown]
# Importing the required libraries Analysing the dataset by check various aspects..
#
# Data Visualization is done by Univariate bivariate and multivariate to get a better insight of the data..
#
# Exploratory data analysis and Data Preprocessing is used to prepare the data for modeling
